# %%
import warnings
warnings.filterwarnings('ignore')
import sys
sys.path.append( '../cartagen4py/algorithms/points' )
from swinging_arm import *

# %% [markdown]
# # Parameters

# %%
puntos = gpd.read_file('./data/puntos/puntos1.shp')
r = 10

# %% [markdown]
# ## Create and draw the results

# %%
polygons = swing(puntos, r)
draw_swingingArm(puntos, polygons)
# Out:
# [<POLYGON ((13 99, 9 97, 3 94, 4 87, 5 83, 7 81, 12 89, 15 88, 20 87, 15 95, ...>]
# Polygons drawn: 1

# %% [markdown]
# ## Same arm length but clockwise direction for angle calculation

# %%
polygons = swing(puntos, r, 'clockwise')
draw_swingingArm(puntos, polygons)
# Out:
# [<POLYGON ((13 99, 15 95, 20 87, 15 88, 10 86, 7 81, 5 83, 4 87, 3 94, 9 97, ...>]
# Polygons drawn: 1

# %% [markdown]
# ## With a bigger arm length

# %%
polygons = swing(puntos, 15)
draw_swingingArm(puntos, polygons)
# Out:
# [<POLYGON ((13 99, 9 97, 3 94, 4 87, 5 83, 7 81, 20 87, 13 99))>]
# Polygons drawn: 1

# %% [markdown]
# ## With more clusters

# %%
puntos = gpd.read_file('./data/puntos/puntos3.shp')

# %%
polygons = swing(puntos, 15)
draw_swingingArm(puntos, polygons)
# Out:
# [<POLYGON ((89 97, 80 94, 79 93, 77 91, 78 81, 92 83, 93 89, 93 92, 90 96, 89...>, <POLYGON ((9 73, 8 68, 14 58, 16 58, 20 59, 23 60, 25 63, 24 66, 22 70, 9 73))>, <POLYGON ((84 51, 76 50, 72 42, 77 36, 85 35, 89 40, 88 48, 87 50, 84 51))>]
# Polygons drawn: 3
